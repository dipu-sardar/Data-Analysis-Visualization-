# %% [markdown]
# 1. Load the CSV file using pandas.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv("/Users/dipusardar/DIPU/Programming/Data-Analysis/Project 02/movie.csv")
print(df.head())
# Out:
#    User_ID User_Name Country    Genre Movie_Name  Watch_Hours  Rating  \
# 0        1   Anthony  Canada  Romance   Resource          2.6       3
# 1        2      Leah     USA   Action      Seven          4.1       9
# 2        3     Bobby   India   Comedy     Chance          0.7       4
# 3        4     Scott   India  Romance       Late          1.1       6
# 4        5      Tara   India   Sci-Fi   Whatever          4.8       9
#
#   Subscription_Type  Device  Watch_Date
# 0          Standard  Tablet  2025-02-07
# 1           Premium  Tablet  2025-05-10
# 2          Standard  Laptop  2025-03-09
# 3          Standard  Laptop  2025-02-15
# 4             Basic  Mobile  2025-04-14

# %% [markdown]
# 2. Show first 15 rows.

# %%
print(df.head(15))
# Out:
#     User_ID  User_Name Country    Genre Movie_Name  Watch_Hours  Rating  \
# 0         1    Anthony  Canada  Romance   Resource          2.6       3
# 1         2       Leah     USA   Action      Seven          4.1       9
# 2         3      Bobby   India   Comedy     Chance          0.7       4
# 3         4      Scott   India  Romance       Late          1.1       6
# 4         5       Tara   India   Sci-Fi   Whatever          4.8       9
# 5         6      Wendy      UK   Horror     Moment          0.5       7
# 6         7    Melissa  Canada  Romance      Piece          4.3       4
# 7         8   Lawrence   Japan   Comedy     Figure          3.0       1
# 8         9     Rodney   India   Horror       Pass          3.2       9
# 9        10  Stephanie   India  Romance       Move          3.9       2
# 10       11    Heather   Japan   Sci-Fi     Simple          4.3       7
# 11       12     Robert   India   Comedy   Everyone          0.8      10
# 12       13    Michael   Japan   Comedy    Morning          3.6       1
# 13       14   Jennifer   India    Drama        Key          4.1      10
# 14       15       Eric   Japan   Action       Less          1.0       4
#
#    Subscription_Type  Device  Watch_Date
# 0           Standard  Tablet  2025-02-07
# 1            Premium  Tablet  2025-05-10
# 2           Standard  Laptop  2025-03-09
# 3           Standard  Laptop  2025-02-15
# 4              Basic  Mobile  2025-04-14
# 5              Basic  Laptop  2025-02-16
# 6           Standard  Laptop  2025-02-12
# 7            Premium      TV  2025-06-09
# 8           Standard  Tablet  2025-06-26
# 9           Standard      TV  2025-04-13
# 10           Premium      TV  2025-03-03
# 11             Basic      TV  2025-02-07
# 12          Standard  Laptop  2025-06-30
# 13          Standard  Mobile  2025-06-16
# 14           Premium  Laptop  2025-06-26

# %% [markdown]
# 3. Display all column names.

# %%
print(df.columns)
# Out:
# Index(['User_ID', 'User_Name', 'Country', 'Genre', 'Movie_Name', 'Watch_Hours',
#        'Rating', 'Subscription_Type', 'Device', 'Watch_Date'],
#       dtype='str')

# %% [markdown]
# 4. Find total rows and columns.

# %%
print(df.shape)
# Out:
# (300, 10)

# %% [markdown]
# 5. Check null values.

# %%
print(df.isnull().sum())
# Out:
# User_ID              0
# User_Name            0
# Country              0
# Genre                0
# Movie_Name           0
# Watch_Hours          0
# Rating               0
# Subscription_Type    0
# Device               0
# Watch_Date           0
# dtype: int64

# %% [markdown]
# 6. Find unique genres.

# %%
print(df['Genre'].unique())
# Out:
# <StringArray>
# ['Romance', 'Action', 'Comedy', 'Sci-Fi', 'Horror', 'Drama']
# Length: 6, dtype: str

# %% [markdown]
# 8. Show only users from USA.

# %%
print(df[df["Country"]=="USA"])
# Out:
#      User_ID User_Name Country   Genre  Movie_Name  Watch_Hours  Rating  \
# 1          2      Leah     USA  Action       Seven          4.1       9
# 17        18     David     USA  Comedy   Sometimes          0.7       8
# 18        19      Sean     USA  Action      Little          0.7       4
# 19        20      Anna     USA  Horror     Reality          4.8       7
# 23        24    Ronald     USA  Action     Prevent          0.5       5
# ..       ...       ...     ...     ...         ...          ...     ...
# 266      267     Cindy     USA  Horror      School          2.4       2
# 270      271     Penny     USA  Horror       Heavy          4.6       7
# 279      280  Margaret     USA  Comedy  Television          3.4       4
# 289      290     Karen     USA  Sci-Fi      Entire          1.9       9
# 298      299  Jonathan     USA   Drama       Money          4.4       4
#
#     Subscription_Type  Device  Watch_Date
# 1             Premium  Tablet  2025-05-10
# 17              Basic  Laptop  2025-02-11
# 18           Standard  Mobile  2025-01-25
# 19           Standard  Tablet  2025-06-26
# 23            Premium      TV  2025-03-11
# ..                ...     ...         ...
# 266           Premium  Laptop  2025-03-10
# 270          Standard  Laptop  2025-05-20
# 279          Standard  Tablet  2025-02-09
# 289             Basic  Laptop  2025-02-15
# 298             Basic  Laptop  2025-05-19
#
# [68 rows x 10 columns]

# %% [markdown]
# 9. Find movies with Rating greater than 8.

# %%
print(df.head())
print(df[df['Rating'] > 8])
# Out:
#    User_ID User_Name Country    Genre Movie_Name  Watch_Hours  Rating  \
# 0        1   Anthony  Canada  Romance   Resource          2.6       3
# 1        2      Leah     USA   Action      Seven          4.1       9
# 2        3     Bobby   India   Comedy     Chance          0.7       4
# 3        4     Scott   India  Romance       Late          1.1       6
# 4        5      Tara   India   Sci-Fi   Whatever          4.8       9
#
#   Subscription_Type  Device  Watch_Date
# 0          Standard  Tablet  2025-02-07
# 1           Premium  Tablet  2025-05-10
# 2          Standard  Laptop  2025-03-09
# 3          Standard  Laptop  2025-02-15
# 4             Basic  Mobile  2025-04-14
#      User_ID    User_Name Country    Genre   Movie_Name  Watch_Hours  Rating  \
# 1          2         Leah     USA   Action        Seven          4.1       9
# 4          5         Tara   India   Sci-Fi     Whatever          4.8       9
# 8          9       Rodney   India   Horror         Pass          3.2       9
# 11        12       Robert   India   Comedy     Everyone          0.8      10
# 13        14     Jennifer   India    Drama          Key          4.1      10
# 32        33        Scott      UK   Sci-Fi         High          2.4      10
# 39        40        Karen     USA  Romance       Remain          3.2       9
# 50        51        Tyler      UK   Sci-Fi          Bar          1.5       9
# 61        62        David     USA   Sci-Fi    Including          1.8       9
# 63        64        Paige      UK   Sci-Fi        Claim          0.9      10
# 66        67         John   India   Comedy      Perform          0.5      10
# 74        75        Scott   Japan    Drama      Natural          2.6      10
# 81        82       Angela   Japan    Drama         Read          3.1       9
# 87        88      Randall  Canada  Romance         Pull          4.3       9
# 89        90      Michele      UK  Romance         Blue          2.4      10
# 91        92      Michael   India   Action    Condition          3.7      10
# 102      103         Cory     USA   Horror       Senior          1.1       9
# 103      104        Roger   India   Horror     Industry          3.7      10
# 105      106        Donna   Japan  Romance       Factor          0.7       9
# 108      109        Peter   Japan   Horror         Keep          4.6       9
# 116      117       Arthur   India   Action        Model          3.9      10
# 121      122       Joseph     USA   Sci-Fi       Worker          4.5      10
# 122      123      Melissa     USA    Drama       Remain          1.6      10
# 126      127        Frank      UK   Action         News          3.3       9
# 134      135     Benjamin   Japan    Drama         Baby          0.7       9
# 135      136        Kayla   Japan   Horror      Because          1.3       9
# 137      138       Adrian   India    Drama        Start          4.8      10
# 140      141       Stacey   Japan  Romance     Customer          1.3       9
# 141      142   Jacqueline   India   Action        Small          3.9       9
# 147      148      Vanessa     USA   Action  Environment          1.2      10
# 164      165       Thomas     USA   Horror      Control          0.9      10
# 168      169      Tiffany   India   Action          Red          3.8       9
# 171      172        Amber      UK    Drama          Act          3.9       9
# 177      178         Dana     USA   Sci-Fi        Plant          3.6      10
# 179      180         Marc     USA  Romance     Employee          4.7      10
# 187      188        Tammy     USA   Comedy         Here          3.5      10
# 199      200        Renee      UK    Drama       Debate          3.0       9
# 201      202        Lacey     USA   Comedy         Grow          4.9      10
# 204      205         Sean   Japan   Sci-Fi         Tree          3.4       9
# 219      220  Christopher     USA   Sci-Fi        Color          1.9       9
# 221      222         Cole   India   Comedy          Two          2.6      10
# 226      227       Thomas   Japan    Drama     Continue          1.5       9
# 242      243       Samuel      UK   Comedy         Test          4.9       9
# 243      244        Susan   India   Action       Accept          3.4      10
# 245      246     Brittney     USA   Horror         Grow          3.4       9
# 249      250       Jeremy      UK    Drama        Owner          2.7      10
# 250      251        Scott      UK  Romance   Population          4.5      10
# 251      252         Paul   India   Sci-Fi   Television          0.5       9
# 253      254        David     USA   Comedy         Once          3.4       9
# 255      256       Marcus   Japan   Sci-Fi         Pull          2.7      10
# 257      258     Brittany  Canada    Drama     American          3.3       9
# 262      263     Theodore  Canada   Sci-Fi         Feel          3.0       9
# 265      266      Matthew  Canada   Sci-Fi        Night          4.4      10
# 272      273      Kristen   India    Drama       Public          3.6      10
# 283      284    Alexander   Japan    Drama      Against          4.1       9
# 284      285       Stacey  Canada   Horror          Job          4.1      10
# 287      288       Ronald  Canada   Action   Generation          4.5      10
# 289      290        Karen     USA   Sci-Fi       Entire          1.9       9
# 293      294       Joshua  Canada   Sci-Fi          Tax          2.5      10
# 297      298       Sierra   India   Horror  Opportunity          2.1      10
#
#     Subscription_Type  Device  Watch_Date
# 1             Premium  Tablet  2025-05-10
# 4               Basic  Mobile  2025-04-14
# 8            Standard  Tablet  2025-06-26
# 11              Basic      TV  2025-02-07
# 13           Standard  Mobile  2025-06-16
# 32              Basic  Mobile  2025-04-24
# 39              Basic  Mobile  2025-01-08
# 50              Basic  Tablet  2025-04-05
# 61            Premium      TV  2025-05-17
# 63            Premium  Mobile  2025-05-16
# 66           Standard  Tablet  2025-04-19
# 74            Premium      TV  2025-06-07
# 81           Standard      TV  2025-03-04
# 87            Premium  Mobile  2025-05-04
# 89              Basic  Mobile  2025-04-06
# 91           Standard  Mobile  2025-04-27
# 102          Standard  Mobile  2025-01-19
# 103           Premium  Laptop  2025-05-31
# 105           Premium      TV  2025-04-13
# 108             Basic  Tablet  2025-05-23
# 116             Basic  Mobile  2025-03-08
# 121             Basic      TV  2025-05-30
# 122          Standard      TV  2025-06-26
# 126             Basic  Laptop  2025-02-15
# 134           Premium  Mobile  2025-05-29
# 135           Premium  Mobile  2025-06-19
# 137             Basic  Mobile  2025-02-26
# 140             Basic  Laptop  2025-01-14
# 141           Premium      TV  2025-05-23
# 147             Basic  Tablet  2025-04-25
# 164             Basic      TV  2025-05-25
# 168          Standard  Mobile  2025-03-12
# 171           Premium  Tablet  2025-01-16
# 177           Premium      TV  2025-02-26
# 179             Basic  Laptop  2025-05-29
# 187           Premium  Laptop  2025-05-10
# 199           Premium  Tablet  2025-02-13
# 201          Standard  Tablet  2025-06-02
# 204             Basic  Mobile  2025-06-14
# 219           Premium      TV  2025-06-06
# 221             Basic  Tablet  2025-06-22
# 226             Basic  Tablet  2025-01-29
# 242           Premium  Laptop  2025-01-14
# 243          Standard  Mobile  2025-01-22
# 245             Basic  Tablet  2025-06-24
# 249             Basic  Tablet  2025-04-13
# 250           Premium  Laptop  2025-05-18
# 251           Premium  Mobile  2025-01-12
# 253             Basic  Mobile  2025-06-20
# 255          Standard  Laptop  2025-01-27
# 257          Standard  Laptop  2025-01-14
# 262             Basic      TV  2025-02-06
# 265           Premium  Tablet  2025-04-30
# 272             Basic  Laptop  2025-01-24
# 283           Premium  Mobile  2025-06-24
# 284             Basic      TV  2025-03-12
# 287           Premium  Mobile  2025-04-25
# 289             Basic  Laptop  2025-02-15
# 293             Basic  Tablet  2025-05-04
# 297             Basic  Mobile  2025-01-13

# %% [markdown]
# 10. Calculate average Watch_Hours.

# %%
print(df['Watch_Hours'].mean())
# Out:
# 2.8366666666666664

# %% [markdown]
# 11. Find highest and lowest ratings.

# %%
print(df["Rating"].min())
print(df["Rating"].max())
# Out:
# 1
# 10

# %% [markdown]
# 12. Find average rating for each genre.

# %%
print(df.columns)
print(df.groupby('Genre')['Rating'].mean())
# Out:
# Index(['User_ID', 'User_Name', 'Country', 'Genre', 'Movie_Name', 'Watch_Hours',
#        'Rating', 'Subscription_Type', 'Device', 'Watch_Date'],
#       dtype='str')
# Genre
# Action     5.844444
# Comedy     5.423077
# Drama      5.549020
# Horror     5.152174
# Romance    4.929825
# Sci-Fi     6.224490
# Name: Rating, dtype: float64

# %% [markdown]
# 13. Find total watch hours for each country.

# %%
print(df.groupby('Country')['Watch_Hours'].sum())
# Out:
# Country
# Canada    168.0
# India     191.2
# Japan     192.8
# UK        110.8
# USA       188.2
# Name: Watch_Hours, dtype: float64

# %% [markdown]
# 14. Find most used device.

# %%
print(df.columns)
print(df.value_counts("Device"))
# Out:
# Index(['User_ID', 'User_Name', 'Country', 'Genre', 'Movie_Name', 'Watch_Hours',
#        'Rating', 'Subscription_Type', 'Device', 'Watch_Date'],
#       dtype='str')
# Device
# TV        81
# Mobile    78
# Tablet    71
# Laptop    70
# Name: count, dtype: int64

# %% [markdown]
# 15. Find top 10 highest rated movies.

# %%
print(df.sort_values(by='Rating' ,  ascending=True,).head(10))
# Out:
#      User_ID User_Name Country    Genre Movie_Name  Watch_Hours  Rating  \
# 149      150   Michele     USA   Horror     Parent          0.7       1
# 27        28   Michael     USA  Romance       Room          1.1       1
# 143      144  Nicholas   India  Romance     Nature          0.6       1
# 228      229    Albert     USA    Drama     Simple          1.4       1
# 224      225   Caitlin   India    Drama       Will          3.4       1
# 209      210    Monica  Canada   Action   Discover          2.9       1
# 79        80   Felicia     USA  Romance      Cause          1.2       1
# 45        46    Donald   Japan   Sci-Fi   Recently          3.8       1
# 246      247     Emily     USA   Action    Foreign          4.3       1
# 97        98   Rebecca   Japan  Romance       Draw          3.9       1
#
#     Subscription_Type  Device  Watch_Date
# 149          Standard  Tablet  2025-02-27
# 27           Standard  Tablet  2025-05-22
# 143             Basic  Laptop  2025-01-28
# 228           Premium  Laptop  2025-01-27
# 224             Basic      TV  2025-05-26
# 209           Premium      TV  2025-04-18
# 79              Basic  Tablet  2025-06-19
# 45           Standard  Mobile  2025-05-01
# 246          Standard      TV  2025-01-31
# 97            Premium      TV  2025-06-30

# %% [markdown]
# 16. Find average watch hours by subscription type.

# %%
print(df.groupby('Subscription_Type')['Watch_Hours'].mean())
# Out:
# Subscription_Type
# Basic       2.783333
# Premium     2.936792
# Standard    2.780233
# Name: Watch_Hours, dtype: float64

# %% [markdown]
# 17. Sort dataset by Rating descending.

# %%
print(df.sort_values(by='Rating', ascending=False))
# Out:
#      User_ID User_Name Country    Genre  Movie_Name  Watch_Hours  Rating  \
# 89        90   Michele      UK  Romance        Blue          2.4      10
# 74        75     Scott   Japan    Drama     Natural          2.6      10
# 137      138    Adrian   India    Drama       Start          4.8      10
# 287      288    Ronald  Canada   Action  Generation          4.5      10
# 32        33     Scott      UK   Sci-Fi        High          2.4      10
# ..       ...       ...     ...      ...         ...          ...     ...
# 261      262     Isaac   Japan   Action          Go          4.2       1
# 228      229    Albert     USA    Drama      Simple          1.4       1
# 79        80   Felicia     USA  Romance       Cause          1.2       1
# 76        77   Cameron   India  Romance         Top          4.9       1
# 267      268   Jessica  Canada    Drama         Say          3.8       1
#
#     Subscription_Type  Device  Watch_Date
# 89              Basic  Mobile  2025-04-06
# 74            Premium      TV  2025-06-07
# 137             Basic  Mobile  2025-02-26
# 287           Premium  Mobile  2025-04-25
# 32              Basic  Mobile  2025-04-24
# ..                ...     ...         ...
# 261          Standard  Laptop  2025-06-01
# 228           Premium  Laptop  2025-01-27
# 79              Basic  Tablet  2025-06-19
# 76            Premium  Tablet  2025-03-16
# 267          Standard  Tablet  2025-05-13
#
# [300 rows x 10 columns]

# %% [markdown]
# 18. Find users who watched more than 4 hours.

# %%
print(df[df['Watch_Hours'] > 4])
# Out:
#      User_ID User_Name Country    Genre  Movie_Name  Watch_Hours  Rating  \
# 1          2      Leah     USA   Action       Seven          4.1       9
# 4          5      Tara   India   Sci-Fi    Whatever          4.8       9
# 6          7   Melissa  Canada  Romance       Piece          4.3       4
# 10        11   Heather   Japan   Sci-Fi      Simple          4.3       7
# 13        14  Jennifer   India    Drama         Key          4.1      10
# ..       ...       ...     ...      ...         ...          ...     ...
# 284      285    Stacey  Canada   Horror         Job          4.1      10
# 285      286     Craig  Canada   Comedy     Meeting          4.3       1
# 287      288    Ronald  Canada   Action  Generation          4.5      10
# 296      297      Tina   Japan   Comedy        Must          4.3       5
# 298      299  Jonathan     USA    Drama       Money          4.4       4
#
#     Subscription_Type  Device  Watch_Date
# 1             Premium  Tablet  2025-05-10
# 4               Basic  Mobile  2025-04-14
# 6            Standard  Laptop  2025-02-12
# 10            Premium      TV  2025-03-03
# 13           Standard  Mobile  2025-06-16
# ..                ...     ...         ...
# 284             Basic      TV  2025-03-12
# 285          Standard      TV  2025-03-13
# 287           Premium  Mobile  2025-04-25
# 296           Premium  Mobile  2025-03-11
# 298             Basic  Laptop  2025-05-19
#
# [71 rows x 10 columns]

# %% [markdown]
# 19. Create a new column called Bonus_Hours (Watch_Hours * 0.10).

# %%
df['Bonus_Hours'] = df['Watch_Hours'] * 0.10

print(df['Bonus_Hours'])
# Out:
# 0      0.26
# 1      0.41
# 2      0.07
# 3      0.11
# 4      0.48
#        ...
# 295    0.17
# 296    0.43
# 297    0.21
# 298    0.44
# 299    0.39
# Name: Bonus_Hours, Length: 300, dtype: float64

# %% [markdown]
# 20. Create another column called Total_Hours after adding Bonus_Hours.

# %%
df['Total_Hour'] = df['Watch_Hours'] + df['Bonus_Hours']

print(df['Total_Hour'])
# Out:
# 0      2.86
# 1      4.51
# 2      0.77
# 3      1.21
# 4      5.28
#        ...
# 295    1.87
# 296    4.73
# 297    2.31
# 298    4.84
# 299    4.29
# Name: Total_Hour, Length: 300, dtype: float64

# %% [markdown]
# Now, it is time to move on for matplotlib questions

# %% [markdown]
# 21. Create a bar chart for Genre vs Average Rating.

# %%
#bar chart করার আগে আমাকে অবশ্যই অবশ্যই সিলেক্ট করে নিতে হবে pandas দিয়ে 
chart = df.groupby('Genre')['Rating'].mean()
plt.figure(figsize=(5,3))
plt.bar(
    chart.index,
    chart.values,
    color = ['green', 'orange', 'black', 'red', 'yellow', 'blue']
)
plt.title('Genre vs Average Rating')
plt.xlabel('Genre')
plt.ylabel('Average Rating')

plt.tight_layout()
plt.show()
